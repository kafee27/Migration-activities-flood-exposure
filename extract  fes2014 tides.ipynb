# %%
from __future__ import print_function

import os
import datetime
import numpy as np
import matplotlib.pyplot as plt
import ipywidgets as widgets
import IPython.display

# import tide programs
import pyTMD.io
import pyTMD.time
import pyTMD.predict
import pyTMD.tools
import pyTMD.utilities

# autoreload
# %load_ext autoreload
# %autoreload 2

# %%
# available model list
model_list = sorted(pyTMD.io.model.ocean_elevation())
# display widgets for setting directory and model
TMDwidgets = pyTMD.tools.widgets()
TMDwidgets.model.options = model_list
TMDwidgets.model.value = 'FES2014'
widgets.VBox([
    TMDwidgets.directory,
    TMDwidgets.model,
    TMDwidgets.atlas,
    TMDwidgets.compress,
    TMDwidgets.datepick
])

# %%
m=[pyTMD.tools.leaflet(center=(22.6244373,116.3970718), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(22.536417,116.3503723), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(22.4483948,116.3036804), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(22.3603745,116.2569885), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(22.2809906,116.1976929), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(22.2080154,116.1298523), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(22.1350422,116.0620041), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(22.062067,115.9941635), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.9890919,115.9263153), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.9215469,115.8533096), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.8585014,115.7761536), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.7954559,115.6989975), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.7324104,115.6218338), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.6693649,115.5446777), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.614212,115.462059), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.5658245,115.3749619), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.517437,115.2878571), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.4690495,115.2007523), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.4206619,115.1136551), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.3722744,115.0265503), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.3238869,114.9394531), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.2754993,114.8523483), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.2271118,114.7652512), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.1787243,114.6781464), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.1386871,114.5874329), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.1094131,114.4921951), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.080183,114.3969345), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.0509529,114.3016815), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.0217209,114.2064285), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.9930935,114.1109924), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.9653797,114.0152817), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.9376755,113.9195709), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.9099712,113.8238602), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.882267,113.7281494), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.8545609,113.6324387), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.8268566,113.5367279), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.7991524,113.4410172), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.7714481,113.3453064), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.7437439,113.2495956), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.7168217,113.1536713), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.6916714,113.0572586), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.6665707,112.9608307), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.64147,112.8644028), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.6163692,112.7679825), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.5984268,112.6703186), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.6005116,112.5707397), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.6033058,112.471138), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.6060982,112.3715439), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.6088924,112.2719421), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.6356163,112.1783676), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.68536,112.0920334), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.7351036,112.0056992), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.7848473,111.9193649), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.8345909,111.8330307), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.8982086,111.7587128), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(20.9778843,111.6988754), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.05756,111.6390457), zoom=12,zoom_control=True, marker_control=True),
   pyTMD.tools.leaflet(center=(21.1372337,111.579216), zoom=12,zoom_control=True, marker_control=True)]

# %%
import pandas as pd
i=0
while i<58:
    # %matplotlib widget

    # get model parameters
    model = pyTMD.io.model(TMDwidgets.directory.value,
        format=TMDwidgets.atlas.value,
        compressed=TMDwidgets.compress.value
       ).elevation(TMDwidgets.model.value)

    # convert from calendar date to days relative to Jan 1, 1992 (48622 MJD)
    YMD = TMDwidgets.datepick.value
    # calculate a weeks forecast every minute
    minutes = np.arange(15*1440)#这里输入日期范围
    # convert time from MJD to days relative to Jan 1, 1992 (48622 MJD)
    tide_time = pyTMD.time.convert_calendar_dates(YMD.year, YMD.month,
        YMD.day, minute=minutes)
    hours = minutes/60.0

    # create plot with tidal displacements, high and low tides and dates
    fig,ax1 = plt.subplots(num=1)
    xmax = np.ceil(hours[-1]).astype('i')
    l1, = ax1.plot([], [], 'k')
    l2, = ax1.plot([], [], 'r*')
    l3, = ax1.plot([], [], 'b*')
    for h in range(24,xmax,24):
        ax1.axvline(h,color='gray',lw=0.5,ls='dashed',dashes=(11,5))
    ax1.set_xlim(0,xmax)
    ax1.set_ylabel(f'{model.name} Tidal Displacement [cm]')
    args = (YMD.year,YMD.month,YMD.day)
    ax1.set_xlabel('Time from {0:4d}-{1:02d}-{2:02d} UTC [Hours]'.format(*args))
    ttl = ax1.set_title(None)
    fig.subplots_adjust(left=0.10,right=0.98,bottom=0.10,top=0.95)

    # delta time (TT - UT1) file
    delta_file = pyTMD.utilities.get_data_path(['data','merged_deltat.data'])

    # read tidal constants and interpolate to leaflet points
    if model.format in ('OTIS','ATLAS','ESR'):
        constituents = pyTMD.io.OTIS.read_constants(
            model.grid_file, model.model_file,
            model.projection, type=model.type,
            grid=model.format)
        c = constituents.fields
        DELTAT = np.zeros_like(tide_time)
    elif (model.format == 'netcdf'):
        constituents = pyTMD.io.ATLAS.read_constants(
            model.grid_file, model.model_file,
            type=model.type, compressed=model.compressed)
        c = constituents.fields
        DELTAT = np.zeros_like(tide_time)
    elif (model.format == 'GOT'):
        constituents = pyTMD.io.GOT.read_constants(
            model.model_file, compressed=model.compressed)
        c = constituents.fields
        # interpolate delta times from calendar dates to tide time
        DELTAT = pyTMD.time.interpolate_delta_time(delta_file, tide_time)
    elif (model.format == 'FES'):
        constituents = pyTMD.io.FES.read_constants(model.model_file,
            type=model.type, version=model.version,
            compressed=model.compressed)
        c = model.constituents
        # interpolate delta times from calendar dates to tide time
        DELTAT = pyTMD.time.interpolate_delta_time(delta_file, tide_time)

    # update the tide prediction and plot
    # leaflet location
    LAT,LON = np.copy(m[i].marker.location)
    # verify longitudes
    LON = m[i].wrap_longitudes(LON)
    if model.format in ('OTIS','ATLAS','ESR'):
        amp,ph,D = pyTMD.io.OTIS.interpolate_constants(
            np.atleast_1d(LON), np.atleast_1d(LAT),
            constituents, model.projection, type=model.type,
            method='spline', extrapolate=True)
    elif (model.format == 'netcdf'):
        amp,ph,D = pyTMD.io.ATLAS.interpolate_constants(
            np.atleast_1d(LON), np.atleast_1d(LAT),
            constituents, type=model.type, scale=model.scale,
            method='spline', extrapolate=True)
    elif (model.format == 'GOT'):
        amp,ph = pyTMD.io.GOT.interpolate_constants(
            np.atleast_1d(LON), np.atleast_1d(LAT),
            constituents, scale=model.scale,
            method='spline', extrapolate=True)
    elif (model.format == 'FES'):
        amp,ph = pyTMD.io.FES.interpolate_constants(
            np.atleast_1d(LON), np.atleast_1d(LAT),
            constituents, scale=model.scale,
            method='spline', extrapolate=True)
    # calculate complex phase in radians for Euler's
    cph = -1j*ph*np.pi/180.0
    # calculate constituent oscillation
    hc = amp*np.exp(cph)
    # predict tidal elevations at time 1 and infer minor corrections
    TIDE = pyTMD.predict.time_series(tide_time, hc, c,
        deltat=DELTAT, corrections=model.format)
    MINOR = pyTMD.predict.infer_minor(tide_time, hc, c,
        deltat=DELTAT, corrections=model.format)
    TIDE.data[:] += MINOR.data[:]
    # convert to centimeters
    TIDE.data[:] *= 100.0

    # differentiate to calculate high and low tides
    diff = np.zeros_like(tide_time, dtype=np.float64)
    # forward differentiation for starting point
    diff[0] = TIDE.data[1] - TIDE.data[0]
    # backward differentiation for end point
    diff[-1] = TIDE.data[-1] - TIDE.data[-2]
    # centered differentiation for all others
    diff[1:-1] = (TIDE.data[2:] - TIDE.data[0:-2])/2.0
    # indices of high and low tides
    htindex, = np.nonzero((np.sign(diff[0:-1]) >= 0) & (np.sign(diff[1:]) < 0))
    ltindex, = np.nonzero((np.sign(diff[0:-1]) <= 0) & (np.sign(diff[1:]) > 0))
    # update plot data
    l1.set_data(hours, TIDE.data)
    l2.set_data(hours[htindex], TIDE.data[htindex])
    l3.set_data(hours[ltindex], TIDE.data[ltindex])
    # update plot title
    ttl.set_text(u'{0:0.6f}\u00b0N {1:0.6f}\u00b0W'.format(LAT,LON))
    ax1.relim()
    ax1.autoscale_view()
    #fig.canvas.draw()
    dataframe=pd.DataFrame(TIDE.data)
    dataframe.to_csv('D:\\fes2014\\2020529612\\'+'test'+str(i)+'.csv',index=False,sep=',')
    # watch marker location for changes
    #m.marker_text.observe(update_tide_prediction)
    i=i+1
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # #备份

# %%
# default coordinates to use
# #LAT,LON = (32.86710263,-117.25750387)
# i=0
# m0 = pyTMD.tools.leaflet(center=(22.6244373,116.3970718), zoom=12,
#     zoom_control=True, marker_control=True)
# m1 = pyTMD.tools.leaflet(center=(22.536417,116.3503723), zoom=12,
#     zoom_control=True, marker_control=True)
# m2 = pyTMD.tools.leaflet(center=(22.4483948,116.3036804), zoom=12,
#     zoom_control=True, marker_control=True)
# m3 = pyTMD.tools.leaflet(center=(22.3603745,116.2569885), zoom=12,
#     zoom_control=True, marker_control=True)
# m4 = pyTMD.tools.leaflet(center=(22.2809906,116.1976929), zoom=12,
#     zoom_control=True, marker_control=True)
# m5 = pyTMD.tools.leaflet(center=(22.2080154,116.1298523), zoom=12,
#     zoom_control=True, marker_control=True)
# m6 = pyTMD.tools.leaflet(center=(22.1350422,116.0620041), zoom=12,
#     zoom_control=True, marker_control=True)
# m7 = pyTMD.tools.leaflet(center=(22.062067,115.9941635), zoom=12,
#     zoom_control=True, marker_control=True)
# m8 = pyTMD.tools.leaflet(center=(21.9890919,115.9263153), zoom=12,
#     zoom_control=True, marker_control=True)
# m9 = pyTMD.tools.leaflet(center=(21.9215469,115.8533096), zoom=12,
#     zoom_control=True, marker_control=True)
# m10 = pyTMD.tools.leaflet(center=(21.8585014,115.7761536), zoom=12,
#     zoom_control=True, marker_control=True)
# m11 = pyTMD.tools.leaflet(center=(21.7954559,115.6989975), zoom=12,
#     zoom_control=True, marker_control=True)
# m12 = pyTMD.tools.leaflet(center=(21.7324104,115.6218338), zoom=12,
#     zoom_control=True, marker_control=True)
# m13 = pyTMD.tools.leaflet(center=(21.6693649,115.5446777), zoom=12,
#     zoom_control=True, marker_control=True)
# m14 = pyTMD.tools.leaflet(center=(21.614212,115.462059), zoom=12,
#     zoom_control=True, marker_control=True)
# m15 = pyTMD.tools.leaflet(center=(21.5658245,115.3749619), zoom=12,
#     zoom_control=True, marker_control=True)
# m16 = pyTMD.tools.leaflet(center=(21.517437,115.2878571), zoom=12,
#     zoom_control=True, marker_control=True)
# m17 = pyTMD.tools.leaflet(center=(21.4690495,115.2007523), zoom=12,
#     zoom_control=True, marker_control=True)
# m18 = pyTMD.tools.leaflet(center=(21.4206619,115.1136551), zoom=12,
#     zoom_control=True, marker_control=True)
# m19 = pyTMD.tools.leaflet(center=(21.3722744,115.0265503), zoom=12,
#     zoom_control=True, marker_control=True)
# m20 = pyTMD.tools.leaflet(center=(21.3238869,114.9394531), zoom=12,
#     zoom_control=True, marker_control=True)
# m21 = pyTMD.tools.leaflet(center=(21.2754993,114.8523483), zoom=12,
#     zoom_control=True, marker_control=True)
# m22 = pyTMD.tools.leaflet(center=(21.2271118,114.7652512), zoom=12,
#     zoom_control=True, marker_control=True)
# m23 = pyTMD.tools.leaflet(center=(21.1787243,114.6781464), zoom=12,
#     zoom_control=True, marker_control=True)
# m24 = pyTMD.tools.leaflet(center=(21.1386871,114.5874329), zoom=12,
#     zoom_control=True, marker_control=True)
# m25 = pyTMD.tools.leaflet(center=(21.1094131,114.4921951), zoom=12,
#     zoom_control=True, marker_control=True)
# m26 = pyTMD.tools.leaflet(center=(21.080183,114.3969345), zoom=12,
#     zoom_control=True, marker_control=True)
# m27 = pyTMD.tools.leaflet(center=(21.0509529,114.3016815), zoom=12,
#     zoom_control=True, marker_control=True)
# m28 = pyTMD.tools.leaflet(center=(21.0217209,114.2064285), zoom=12,
#     zoom_control=True, marker_control=True)
# m29 = pyTMD.tools.leaflet(center=(20.9930935,114.1109924), zoom=12,
#     zoom_control=True, marker_control=True)
# m30 = pyTMD.tools.leaflet(center=(20.9653797,114.0152817), zoom=12,
#     zoom_control=True, marker_control=True)
# m31 = pyTMD.tools.leaflet(center=(20.9376755,113.9195709), zoom=12,
#     zoom_control=True, marker_control=True)
# m32 = pyTMD.tools.leaflet(center=(20.9099712,113.8238602), zoom=12,
#     zoom_control=True, marker_control=True)
# m33 = pyTMD.tools.leaflet(center=(20.882267,113.7281494), zoom=12,
#     zoom_control=True, marker_control=True)
# m34 = pyTMD.tools.leaflet(center=(20.8545609,113.6324387), zoom=12,
#     zoom_control=True, marker_control=True)
# m35 = pyTMD.tools.leaflet(center=(20.8268566,113.5367279), zoom=12,
#     zoom_control=True, marker_control=True)
# m36 = pyTMD.tools.leaflet(center=(20.7991524,113.4410172), zoom=12,
#     zoom_control=True, marker_control=True)
# m37 = pyTMD.tools.leaflet(center=(20.7714481,113.3453064), zoom=12,
#     zoom_control=True, marker_control=True)
# m38 = pyTMD.tools.leaflet(center=(20.7437439,113.2495956), zoom=12,
#     zoom_control=True, marker_control=True)
# m39 = pyTMD.tools.leaflet(center=(20.7168217,113.1536713), zoom=12,
#     zoom_control=True, marker_control=True)
# m40 = pyTMD.tools.leaflet(center=(20.6916714,113.0572586), zoom=12,
#     zoom_control=True, marker_control=True)
# m41 = pyTMD.tools.leaflet(center=(20.6665707,112.9608307), zoom=12,
#     zoom_control=True, marker_control=True)
# m42 = pyTMD.tools.leaflet(center=(20.64147,112.8644028), zoom=12,
#     zoom_control=True, marker_control=True)
# m43 = pyTMD.tools.leaflet(center=(20.6163692,112.7679825), zoom=12,
#     zoom_control=True, marker_control=True)
# m44 = pyTMD.tools.leaflet(center=(20.5984268,112.6703186), zoom=12,
#     zoom_control=True, marker_control=True)
# m45 = pyTMD.tools.leaflet(center=(20.6005116,112.5707397), zoom=12,
#     zoom_control=True, marker_control=True)
# m46 = pyTMD.tools.leaflet(center=(20.6033058,112.471138), zoom=12,
#     zoom_control=True, marker_control=True)
# m47 = pyTMD.tools.leaflet(center=(20.6060982,112.3715439), zoom=12,
#     zoom_control=True, marker_control=True)
# m48 = pyTMD.tools.leaflet(center=(20.6088924,112.2719421), zoom=12,
#     zoom_control=True, marker_control=True)
# m49 = pyTMD.tools.leaflet(center=(20.6356163,112.1783676), zoom=12,
#     zoom_control=True, marker_control=True)
# m50 = pyTMD.tools.leaflet(center=(20.68536,112.0920334), zoom=12,
#     zoom_control=True, marker_control=True)
# m51 = pyTMD.tools.leaflet(center=(20.7351036,112.0056992), zoom=12,
#     zoom_control=True, marker_control=True)
# m52 = pyTMD.tools.leaflet(center=(20.7848473,111.9193649), zoom=12,
#     zoom_control=True, marker_control=True)
# m53 = pyTMD.tools.leaflet(center=(20.8345909,111.8330307), zoom=12,
#     zoom_control=True, marker_control=True)
# m54 = pyTMD.tools.leaflet(center=(20.8982086,111.7587128), zoom=12,
#     zoom_control=True, marker_control=True)
# m55 = pyTMD.tools.leaflet(center=(20.9778843,111.6988754), zoom=12,
#     zoom_control=True, marker_control=True)
# m56 = pyTMD.tools.leaflet(center=(21.05756,111.6390457), zoom=12,
#     zoom_control=True, marker_control=True)
# m57 = pyTMD.tools.leaflet(center=(21.1372337,111.579216), zoom=12,
#     zoom_control=True, marker_control=True)
# # show map
# m0.map
# print (m.marker.location)
